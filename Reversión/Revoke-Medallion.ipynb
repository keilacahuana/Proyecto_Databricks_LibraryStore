-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_proy_fin_dev.bronze FROM `daniel.mckinnon@northernlightsbookco.ca`;

-- %%
SHOW GRANTS ON SCHEMA catalog_proy_fin_dev.bronze;

-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_proy_fin_dev.silver FROM `Developers`;

-- %%
SHOW GRANTS ON SCHEMA catalog_proy_fin_dev.silver;

-- %%
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` from `Developers`;
