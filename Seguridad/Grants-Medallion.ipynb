-- %%
GRANT SELECT ON TABLE catalog_proy_fin_dev.golden.golden_payroll_partitioned TO `sofia.redsky@northernlightsbookco.ca`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_proy_fin_dev.bronze TO `Developers`;
GRANT CREATE ON SCHEMA catalog_proy_fin_dev.bronze TO `Developers`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_proy_fin_dev.silver TO `Developers`;
GRANT CREATE ON SCHEMA catalog_proy_fin_dev.silver TO `Developers`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_proy_fin_dev.golden TO `Developers`;
GRANT CREATE ON SCHEMA catalog_proy_fin_dev.golden TO `Developers`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_proy_fin_dev TO `Developers`;

-- %%
SHOW GRANTS ON TABLE catalog_proy_fin_dev.golden.golden_payroll_partitioned;

-- %%
SHOW GRANTS ON SCHEMA catalog_proy_fin_dev.bronze;

-- %%
SHOW GRANTS ON CATALOG catalog_proy_fin_dev;
